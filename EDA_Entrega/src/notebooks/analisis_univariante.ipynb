# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
health = pd.read_csv(r"C:\Users\patri\REPO_PRUEBA\EDA_Patricia_Diez\EDA_Entrega\src\data\health_cleaned.csv")
health.head(3)
# Out:
#    Age      Gender           Job_Role    Industry  Years_of_Experience  \
# 0   32  Non-Binary                 Hr  Healthcare                   13
# 1   40      Female     Data Scientist          It                    3
# 2   59  Non-Binary  Software Engineer   Education                   22
#
#   Work_Location  Hours_Worked_Per_Week  Number_of_Virtual_Meetings  \
# 0        Hybrid                     47                           7
# 1        Remote                     52                           4
# 2        Hybrid                     46                          11
#
#    Work_Life_Balance_Rating Stress_Level Mental_Health_Condition  \
# 0                         2       Medium              Depression
# 1                         1       Medium                 Anxiety
# 2                         5       Medium                 Anxiety
#
#   Access_to_Mental_Health_Resources Productivity_Change  \
# 0                                No            Decrease
# ...

# %%
from bootcampviztools import *

# %%
health.describe()
# Out:
#                Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  5000.000000          5000.000000            5000.000000
# mean     40.995000            17.810200              39.614600
# std      11.296021            10.020412              11.860194
# min      22.000000             1.000000              20.000000
# 25%      31.000000             9.000000              29.000000
# 50%      41.000000            18.000000              40.000000
# 75%      51.000000            26.000000              50.000000
# max      60.000000            35.000000              60.000000
#
#        Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# count                 5000.000000               5000.000000
# mean                     7.559000                  2.984200
# std                      4.636121                  1.410513
# min                      0.000000                  1.000000
# 25%                      4.000000                  2.000000
# ...

# %%
#VARIABLES CATEGORICAS ANALISIS

# %%
# 1. Gender: Pie Chart
gender_counts = health['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Gender Distribution')
plt.show()

# %%
# 2. Job_Role: Barras
plt.figure(figsize=(10, 6))
sns.countplot(data=health, x='Job_Role', order=health['Job_Role'].value_counts().index, palette='viridis')
plt.xticks(rotation=45)
plt.title('Job Role Distribution')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\881004334.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Job_Role', order=health['Job_Role'].value_counts().index, palette='viridis')

# %%
# 3. Work_Location: Pie Chart
work_location_counts = health['Work_Location'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(work_location_counts, labels=work_location_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Work Location Distribution')
plt.show()

# %%
# 4. Mental_Health_Condition: Barras
plt.figure(figsize=(10, 6))
sns.countplot(data=health, x='Mental_Health_Condition', order=health['Mental_Health_Condition'].value_counts().index, palette='mako')
plt.xticks(rotation=45)
plt.title('Mental Health Condition Distribution')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\3361604309.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Mental_Health_Condition', order=health['Mental_Health_Condition'].value_counts().index, palette='mako')

# %%
# 9. Sleep_Quality: Histograma con KDE
plt.figure(figsize=(8, 6))
sns.histplot(health['Sleep_Quality'], bins=20, kde=False, color='pink')
plt.title('Sleep Quality Distribution')
plt.xlabel('Sleep Quality')
plt.show()

# %%
# 10. Access_to_Mental_Health_Resources: Pie Chart
access_counts = health['Access_to_Mental_Health_Resources'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(access_counts, labels=access_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Access to Mental Health Resources')
plt.show()

# %%
# 11. Has_condition: Pie Chart
condition_counts = health['Has_condition'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(condition_counts, labels=condition_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Has Condition')
plt.show()

# %%
# 12. Stress_Level: Barras
plt.figure(figsize=(8, 6))
sns.countplot(data=health, x='Stress_Level', order=['Low', 'Medium', 'High'], palette='coolwarm')
plt.title('Stress Level Distribution')
plt.xlabel('Stress Level')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\2082699994.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Stress_Level', order=['Low', 'Medium', 'High'], palette='coolwarm')

# %%
# 13. Satisfaction_with_Remote_Work: Barras
plt.figure(figsize=(8, 6))
sns.countplot(data=health, x='Satisfaction_with_Remote_Work', order=['Unsatisfied', 'Neutral', 'Satisfied'], palette='cubehelix')
plt.title('Satisfaction with Remote Work')
plt.xlabel('Satisfaction Level')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\2429880007.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Satisfaction_with_Remote_Work', order=['Unsatisfied', 'Neutral', 'Satisfied'], palette='cubehelix')

# %%
# 1. Industry: Barras
plt.figure(figsize=(10, 6))
sns.countplot(data=health, x='Industry', order=health['Industry'].value_counts().index, palette='viridis')
plt.xticks(rotation=45)
plt.title('Industry Distribution')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\3054112102.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Industry', order=health['Industry'].value_counts().index, palette='viridis')

# %%
# 2. Region: Barras
plt.figure(figsize=(10, 6))
sns.countplot(data=health, x='Region', order=health['Region'].value_counts().index, palette='pastel')
plt.xticks(rotation=45)
plt.title('Region Distribution')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\4205924734.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Region', order=health['Region'].value_counts().index, palette='pastel')

# %%
# 6. Physical Activity: Barras
plt.figure(figsize=(8, 6))
sns.countplot(data=health, x='Physical_Activity', order=health['Physical_Activity'].value_counts().index, palette='coolwarm')
plt.xticks(rotation=45)
plt.title('Physical Activity Frequency')
plt.xlabel('Physical Activity')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\241377159.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Physical_Activity', order=health['Physical_Activity'].value_counts().index, palette='coolwarm')

# %%
# 7. Productivity Change: Barras
plt.figure(figsize=(8, 6))
sns.countplot(data=health, x='Productivity_Change', order=health['Productivity_Change'].value_counts().index, palette='mako')
plt.xticks(rotation=45)
plt.title('Productivity Change Distribution')
plt.xlabel('Productivity Change')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_20736\450273968.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=health, x='Productivity_Change', order=health['Productivity_Change'].value_counts().index, palette='mako')

# %%
#VARIABLES NUMERICAS

# %%
# 3. Years of Experience: Histograma con KDE
plt.figure(figsize=(8, 6))
sns.histplot(health['Years_of_Experience'], bins=20, kde=True, color='blue')
plt.title('Years of Experience Distribution')
plt.xlabel('Years of Experience')
plt.show()

# %%
# 4. Number of Virtual Meetings: Histograma
plt.figure(figsize=(8, 6))
sns.histplot(health['Number_of_Virtual_Meetings'], bins=15, kde=False, color='orange')
plt.title('Number of Virtual Meetings Distribution')
plt.xlabel('Number of Virtual Meetings')
plt.show()

# %%
# 8. Hours_Worked_Per_Week: Histograma con KDE
plt.figure(figsize=(8, 6))
sns.histplot(health['Hours_Worked_Per_Week'], bins=20, kde=True, color='purple')
plt.title('Hours Worked Per Week Distribution')
plt.xlabel('Hours Worked Per Week')
plt.show()

# %%
# 5. Company Support for Remote Work: Histograma
plt.figure(figsize=(8, 6))
sns.histplot(health['Company_Support_for_Remote_Work'], bins=5, kde=False, color='green')
plt.title('Company Support for Remote Work Distribution')
plt.xlabel('Company Support Level (1-5)')
plt.show()

# %%
# 7. Age: Histograma con KDE
plt.figure(figsize=(8, 6))
sns.histplot(health['Age'], bins=20, kde=True, color='green')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.show()

# %%
# 5. Work_Life_Balance_Rating: Histograma
plt.figure(figsize=(8, 6))
sns.histplot(health['Work_Life_Balance_Rating'], bins=5, kde=False, color='skyblue')
plt.title('Work Life Balance Rating Distribution')
plt.xlabel('Rating')
plt.show()

# %%
# 6. Social_Isolation_Rating: Histograma
plt.figure(figsize=(8, 6))
sns.histplot(health['Social_Isolation_Rating'], bins=5, kde=False, color='orange')
plt.title('Social Isolation Rating Distribution')
plt.xlabel('Rating')
plt.show()
